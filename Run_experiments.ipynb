# %% [markdown]
# # Introduction
#
# This notebook shows how to excecute the rolling horizon function from the <code>POSYDON.py</code> library, using your forecasts and real data for the wind speed, wave height and electricity prices. This notebook was used to produced the results in the paper.

# %%
import gurobipy as gp
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from time import time
import pickle
from POSYDON import *

# %% [markdown]
# **Import weather dataset**

# %%
weather_data = pd.read_csv("weather_ocean_data_new.csv", index_col=[0], parse_dates=True)
weather_data.head(2)
# Out:
#                            NYE05.wind_speed_100m  NYE05.wave_height  \
# time
# 2019-08-12 00:00:00+00:00               7.993467               0.52
# 2019-08-12 01:00:00+00:00               7.987917               0.58
#
#                            RUWRF.wind_speed_100m  RUWRF.wind_dir_100m  \
# time
# 2019-08-12 00:00:00+00:00               6.988079           234.920095
# 2019-08-12 01:00:00+00:00               8.442663           233.856165
#
#                            NOAA.wave_height  NOAA.wave_dir  \
# time
# 2019-08-12 00:00:00+00:00              0.78         127.98
# 2019-08-12 01:00:00+00:00              0.79         127.92
#
#                            NOAA.wind_speed_10m  NOAA.wind_dir_10m
# time
# 2019-08-12 00:00:00+00:00                 7.37             228.14
# 2019-08-12 01:00:00+00:00                 7.43             229.47

# %% [markdown]
# Select the relevant weather data (forecasts and true data for wind speed and wave height)

# %%
data = np.array(weather_data)
wind_speed_single_true = data[:,0]
wind_speed_single_NWP = data[:,2]
wave_height_true = data[:,1]
wave_height_NWP = data[:,4]

# %% [markdown]
# **Import and process day-ahead electricity price dataset**

# %%
PJM_price_data = pd.read_csv('True_n_LEAR_el_prices_da_comed.csv', index_col=0, parse_dates=True) # Load PJM dataset

el_prices_real = np.array(PJM_price_data['Real price']).reshape(-1)
el_prices_real += 24 #incentive

el_prices_forecast = np.array(PJM_price_data['LEAR 56']).reshape(-1)
el_prices_forecast += 24 #incentive

# %% [markdown]
# **Specify other optimization parameters and prepare to run optimization model**

# %%
Din = 15 # starting day from beginning of dataset (cannot be 0 because historical data are needed to generate scenarios)
N_t=5 # number of wind turbines
N_S = 10 # number of scenarios of the stochastic optimization model
N_D = 9 # LTH length (the total length of the optimization horizon is N_D+1)
rel_gap = 0.001 # control relative optimality gap
exp_num = 1 # select which instance of the RUL experiment sets to solve
max_iter = 3 # number of horizon rolls. If None, then the model is solved until it reaches the end of the dataset

# Bring wind speed data to appropriate shape (time_dim, N_t)
wind_speed_true = np.repeat(wind_speed_single_true[:,np.newaxis],N_t,1)
wind_speed_NWP = np.repeat(wind_speed_single_NWP[:,np.newaxis],N_t,1)

# Create copies of dataset before importing them to the rolling horizon function
wind_speed_true=wind_speed_true.copy()
wave_height_true=wave_height_true.copy()
wind_speed_forecast=wind_speed_NWP.copy()
wave_height_forecast=wave_height_NWP.copy()
el_prices_true=el_prices_real.copy()
el_prices_forecast=el_prices_forecast.copy()

# %% [markdown]
# **Solve the model with a rolling horizon algorithm**

# %%
# Solve the model by the rolling horizon algorithm, and store solutions to sol
sol = solveRollingHorizon( wind_speed_true,
                wave_height_true,
                wind_speed_forecast,
                wave_height_forecast,
                N_S,
                Din,
                el_prices_true,
                el_prices_forecast,
                degr_experiment_num=exp_num,
                deg_data_folder="Data/Degradation Signal info/Data for Optimization",
                power_curve_folder="Data/Yaw power curve",
                mip_gap=rel_gap,
                N_D=N_D,
                max_iter=max_iter)

# Save the solutions in a json file
sol_file = open("test.json", "wb")
pickle.dump(sol, sol_file)
sol_file.close()
# Out:
# Data prepared in  1.4052  sec
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 714717
# Academic license - for non-commercial use only - registered to peterpap94@gmail.com
# Discarded solution information
# ##########################################################
# # POSYDON: Yaw misalignment and maintenance optimization #
# ##########################################################
# Set parameter MIPGap to value 0.001
# Set parameter TimeLimit to value 1800
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1185G7 @ 3.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Academic license - for non-commercial use only - registered to peterpap94@gmail.com
# Optimize a model with 21411 rows, 16356 columns and 123847 nonzeros
# Model fingerprint: 0x73298554
# Variable types: 6930 continuous, 9426 integer (9256 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 6e+03]
#   Objective range  [1e+00, 2e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e-02, 1e+05]
# Presolve removed 18197 rows and 13201 columns
# Presolve time: 0.72s
# Presolved: 3214 rows, 3155 columns, 29584 nonzeros
# Variable types: 894 continuous, 2261 integer (2154 binary)
# Found heuristic solution: objective 211304.60759
# Found heuristic solution: objective 211320.04400
#
# Root relaxation: objective 2.115375e+05, 924 iterations, 0.01 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    211537.45083 211537.451  0.00%     -    0s
#
# Explored 1 nodes (924 simplex iterations) in 0.84 seconds (0.38 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 211537 211320 211305
#
# Optimal solution found (tolerance 1.00e-03)
# Best objective 2.115374508310e+05, best bound 2.115374508310e+05, gap 0.0000%
# Data prepared in  0.0  sec
# Discarded solution information
# *** Initiating day-ahead simulation from input schedule ***
# Set parameter TimeLimit to value 1800
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1185G7 @ 3.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Academic license - for non-commercial use only - registered to peterpap94@gmail.com
# Optimize a model with 2844 rows, 2667 columns and 14560 nonzeros
# Model fingerprint: 0x02f1042c
# Variable types: 855 continuous, 1812 integer (1795 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 6e+03]
#   Objective range  [1e+00, 2e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e-02, 1e+04]
# Presolve removed 2842 rows and 2662 columns
# Presolve time: 0.02s
# Presolved: 2 rows, 5 columns, 9 nonzeros
# Variable types: 1 continuous, 4 integer (4 binary)
# Found heuristic solution: objective 228789.12184
# Found heuristic solution: objective 230654.64128
#
# Root relaxation: cutoff, 2 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      230654.641 230654.641  0.00%     -    0s
#
# Explored 1 nodes (2 simplex iterations) in 0.05 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 230655 228789
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.306546412850e+05, best bound 2.306546412850e+05, gap 0.0000%
# Data prepared in  0.5777  sec
# Discarded solution information
# ##########################################################
# # POSYDON: Yaw misalignment and maintenance optimization #
# ##########################################################
# Set parameter MIPGap to value 0.001
# Set parameter TimeLimit to value 1800
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1185G7 @ 3.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Academic license - for non-commercial use only - registered to peterpap94@gmail.com
# Optimize a model with 21411 rows, 16356 columns and 120390 nonzeros
# Model fingerprint: 0xa14fb1f1
# Variable types: 6930 continuous, 9426 integer (9256 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 6e+03]
#   Objective range  [1e+00, 2e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e-02, 1e+05]
# Presolve removed 18689 rows and 13381 columns
# Presolve time: 0.52s
# Presolved: 2722 rows, 2975 columns, 21424 nonzeros
# Variable types: 811 continuous, 2164 integer (2051 binary)
# Found heuristic solution: objective 269096.89948
# Found heuristic solution: objective 269142.68566
#
# Root relaxation: objective 2.700201e+05, 886 iterations, 0.01 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    270020.05887 270020.059  0.00%     -    0s
#
# Explored 1 nodes (886 simplex iterations) in 0.62 seconds (0.31 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 270020 269143 269097
#
# Optimal solution found (tolerance 1.00e-03)
# Best objective 2.700200588676e+05, best bound 2.700200588676e+05, gap 0.0000%
# Data prepared in  0.001  sec
# Discarded solution information
# *** Initiating day-ahead simulation from input schedule ***
# Set parameter TimeLimit to value 1800
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1185G7 @ 3.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Academic license - for non-commercial use only - registered to peterpap94@gmail.com
# Optimize a model with 2844 rows, 2667 columns and 14053 nonzeros
# Model fingerprint: 0x19076e8a
# Variable types: 855 continuous, 1812 integer (1795 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 6e+03]
#   Objective range  [1e+00, 2e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e-02, 1e+04]
# Presolve removed 2842 rows and 2662 columns
# Presolve time: 0.01s
# Presolved: 2 rows, 5 columns, 9 nonzeros
# Variable types: 1 continuous, 4 integer (4 binary)
# Found heuristic solution: objective 302762.32234
# Found heuristic solution: objective 303513.94592
#
# Root relaxation: cutoff, 2 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      303513.946 303513.946  0.00%     -    0s
#
# Explored 1 nodes (2 simplex iterations) in 0.04 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 303514 302762
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.035139459176e+05, best bound 3.035139459176e+05, gap 0.0000%
# Data prepared in  0.5401  sec
# Discarded solution information
# ##########################################################
# # POSYDON: Yaw misalignment and maintenance optimization #
# ##########################################################
# Set parameter MIPGap to value 0.001
# Set parameter TimeLimit to value 1800
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1185G7 @ 3.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Academic license - for non-commercial use only - registered to peterpap94@gmail.com
# Optimize a model with 21411 rows, 16356 columns and 121311 nonzeros
# Model fingerprint: 0xffac10af
# Variable types: 6930 continuous, 9426 integer (9256 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 6e+03]
#   Objective range  [1e+00, 2e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e-02, 1e+05]
# Presolve removed 17803 rows and 12169 columns
# Presolve time: 0.56s
# Presolved: 3608 rows, 4187 columns, 31916 nonzeros
# Variable types: 1096 continuous, 3091 integer (2966 binary)
# Found heuristic solution: objective 311232.53141
# Found heuristic solution: objective 311879.22716
#
# Root relaxation: objective 3.154601e+05, 1199 iterations, 0.02 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    315460.14925 315460.149  0.00%     -    0s
#
# Explored 1 nodes (1199 simplex iterations) in 0.68 seconds (0.39 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 315460 311879 311233
#
# Optimal solution found (tolerance 1.00e-03)
# Best objective 3.154601492539e+05, best bound 3.154601492539e+05, gap 0.0000%
# Data prepared in  0.0  sec
# Discarded solution information
# *** Initiating day-ahead simulation from input schedule ***
# Set parameter TimeLimit to value 1800
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1185G7 @ 3.00GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Academic license - for non-commercial use only - registered to peterpap94@gmail.com
# Optimize a model with 2844 rows, 2667 columns and 14018 nonzeros
# Model fingerprint: 0x49a1dd52
# Variable types: 855 continuous, 1812 integer (1795 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 6e+03]
#   Objective range  [1e+00, 2e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e-02, 1e+04]
# Presolve removed 2825 rows and 2614 columns
# Presolve time: 0.02s
# Presolved: 19 rows, 53 columns, 137 nonzeros
# Variable types: 11 continuous, 42 integer (42 binary)
# Found heuristic solution: objective 341386.76932
# Found heuristic solution: objective 341471.43138
#
# Root relaxation: objective 3.425324e+05, 18 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    342532.35293 342532.353  0.00%     -    0s
#
# Explored 1 nodes (18 simplex iterations) in 0.04 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 342532 341471 341387
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.425323529266e+05, best bound 3.425323529266e+05, gap 0.0000%

# %%
sol.keys()
# Out:
# dict_keys(['stochastic_sol', 'stochastic_input', 'simulation', 'true_input', 'time_per_roll', 'equivalent_times'])

# %%
sol['equivalent_times'] #shows how many equivalent days of nominal loading the wind turbine has worked
# Out:
# array([[42.        , 53.        , 29.        , 36.        , 23.        ],
#        [42.36907583, 53.34916222, 29.37325782, 36.36907583, 23.36923852],
#        [42.87030849, 53.83683596, 29.85209348, 36.80674061, 23.84416203],
#        [43.67724136, 54.64962941, 30.64568277, 37.65857019, 24.70476565]])

# %%
sol['stochastic_sol'][0].keys()
# Out:
# dict_keys(['STH_sched', 'STH_yaw', 'LTH_sched', 'LTH_yaw', 'DMC', 'crit_coef', 'lambda_is', 'expected_STH_cost', 'remaining_maint_hrs', 'other_params', 'model'])
